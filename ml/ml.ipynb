# %%
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[11], line 16
#      12 from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#      13 import joblib
# ---> 16 df = pd.read_parquet(r".\data\selver")  # Chemin vers ton fichier parquet
#      18 print("Dataset loaded:", df.shape)
#      19 print(df.head())
#
# File /mnt/c/Users/hp/Documents/elbahiaproject/venv/lib/python3.10/site-packages/pandas/io/parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)
#     510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
# ...
